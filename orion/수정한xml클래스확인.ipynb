# %%
import os
import glob
import pymssql
import pandas as pd
import xml.etree.ElementTree as ET

# %%
path = '/home/boyeon/Desktop/orion/make_calssinfo/xml'
xml_list = glob.glob(path + '/*.xml')

# %%
dic = {}
for xml in xml_list:
    tree = ET.parse(xml)
    root = tree.getroot()
    for x in root.findall('object'):
        name = (x.find('name').text)

        if name not in dic:
            dic[name]=0
        dic[name]+=1

# %%
sku_id = dic.keys() 
patch_count= dic.values()
annotation_df = pd.DataFrame({'sku_id': sku_id, 'patch count':patch_count})
annotation_df = annotation_df.sort_values(by='patch count', ascending=False)
annotation_df['sku_id'].nunique()
# Out:
# 315

# %%
annotation_df[annotation_df['patch count']<15]
# Out:
# Empty DataFrame
# Columns: [sku_id, patch count]
# Index: []

# %%
annotation_df[annotation_df['sku_id']=='etc']
# Out:
#    sku_id  patch count
# 90    etc          263

# %%
sorted(annotation_df['sku_id'].unique())
# Out:
# ['10',
#  '100',
#  '101',
#  '102',
#  '104',
#  '105',
#  '106',
#  '108',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '127',
#  '128',
#  '129',
#  '130',
#  '133',
#  '134',
#  '136',
#  '137',
#  '138',
#  '14',
#  '140',
#  '15',
#  '150',
#  '152',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '16',
#  '160',
#  '161',
#  '163',
#  '165',
#  '168',
#  '169',
#  '17',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '176',
#  '179',
#  '18',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '19',
#  '190',
#  '191',
#  '192',
#  '193',
#  '196',
#  '197',
#  '198',
#  '199',
#  '2',
#  '20',
#  '201',
#  '202',
#  '203',
#  '205',
#  '206',
#  '208',
#  '21',
#  '210',
#  '214',
#  '216',
#  '217',
#  '218',
#  '22',
#  '221',
#  '222',
#  '223',
#  '224',
#  '226',
#  '227',
#  '229',
# ...
